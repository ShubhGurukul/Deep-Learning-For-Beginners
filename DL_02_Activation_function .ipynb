# %% [markdown]
# ![image.png](attachment:image.png)
#
# ### We have already used  the sparse_categorical_crossentropy
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)
#
# ### Sample 1 with random weight let say w1 & w2 = 1
#
# ![image.png](attachment:image.png)
#
# ### Sample 2 with error
#
# ![image.png](attachment:image.png)
#
# ### ... Sample 13 with error
# ![image.png](attachment:image.png)
#
# ### Now we are summing the error and the cost function is something look like this
#
# ![image.png](attachment:image.png)
#
# ### There are some other errors as well
#
# ![image.png](attachment:image.png)
#
# ### We have already seen the epochs at the time of model fitting
# ![image.png](attachment:image.png)
#
# ### We have used sparse_categorical_crossentropy but there should not be it whenever we are dealing with logistic regression we need to use 'loss or  error function'
#
# ## https://towardsdatascience.com/why-not-mse-as-a-loss-function-for-logistic-regression-589816b5e03c
